# %% [markdown]
# # 05 Scenario Analysis
#
# This notebook compares how cost and service react under scenario shocks.

# %%
import pandas as pd

scenario = pd.read_csv('../data/outputs/scenario_comparison.csv')
scenario
