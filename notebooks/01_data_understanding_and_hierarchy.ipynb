# %% [markdown]
# # 01 Data Understanding and Hierarchy
#
# This notebook explains the sampled M5 subset, the weekly aggregation logic, and the demand hierarchy used for planning.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weekly = pd.read_csv('../data/processed/weekly_demand.csv', parse_dates=['date'])
hierarchy = pd.read_csv('../data/processed/hierarchy_table.csv')
weekly.shape, hierarchy.shape

# %% [markdown]
# This view helps the S&OP team understand how much data is available after sampling and aggregation.
