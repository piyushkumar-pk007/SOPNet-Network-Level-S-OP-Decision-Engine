# %% [markdown]
# # 02 Hierarchical Forecasting
#
# This notebook compares baseline, statistical, and machine-learning models for weekly demand forecasting.

# %%
import pandas as pd

forecast_results = pd.read_csv('../data/outputs/forecast_results.csv', parse_dates=['date'])
model_comparison = pd.read_csv('../data/outputs/model_comparison.csv')
forecast_results.head()
