# %% [markdown]
# # 03 Production Network Optimization
#
# This notebook reviews the optimization outputs and baseline comparisons.

# %%
import pandas as pd

summary = pd.read_csv('../data/outputs/optimization_summary.csv')
baseline = pd.read_csv('../data/outputs/baseline_comparison.csv')
summary, baseline
