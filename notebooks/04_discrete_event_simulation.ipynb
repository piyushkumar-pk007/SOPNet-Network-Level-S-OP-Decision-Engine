# %% [markdown]
# # 04 Discrete Event Simulation
#
# This notebook reviews simulation outputs and the difference between deterministic and stochastic planning views.

# %%
import pandas as pd

sim_summary = pd.read_csv('../data/outputs/simulation_summary.csv')
sim_results = pd.read_csv('../data/outputs/simulation_results.csv')
sim_summary
